# %%
## 1. Importación de librerías

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 294 kB 2.1 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# Configuración general de estilo
plt.rcParams.update({
    'figure.dpi': 130,
    'font.family': 'DejaVu Sans',
    'axes.spines.top': False,
    'axes.spines.right': False,
})

print('✅ Librerías cargadas correctamente')
# Out:
# ✅ Librerías cargadas correctamente

# %%
## 2. Carga y exploración de datos

# %%
CSV_PATH = 'data/share-of-population-in-extreme-poverty/share-of-population-in-extreme-poverty.csv'
POVERTY_COL = 'Share of population in poverty ($3 a day)'

df = pd.read_csv(CSV_PATH)

print(f'Filas totales : {len(df):,}')
print(f'Columnas      : {df.columns.tolist()}')
print(f'Rango de años : {df["Year"].min()} – {df["Year"].max()}')
df.head()
# Out:
# Filas totales : 59,371
# Columnas      : ['Entity', 'Code', 'Year', 'Share of population in poverty ($3 a day)', 'Population', 'World region according to OWID']
# Rango de años : -10000 – 2026
#         Entity Code   Year  Share of population in poverty ($3 a day)  \
# 0  Afghanistan  AFG -10000                                        NaN
# 1  Afghanistan  AFG  -9000                                        NaN
# 2  Afghanistan  AFG  -8000                                        NaN
# 3  Afghanistan  AFG  -7000                                        NaN
# 4  Afghanistan  AFG  -6000                                        NaN
#
#    Population World region according to OWID
# 0     14737.0                           Asia
# 1     20405.0                           Asia
# 2     28253.0                           Asia
# 3     39120.0                           Asia
# 4     54166.0                           Asia

# %%
## 3. Limpieza y filtrado de datos

# %%
# Año de referencia: el más reciente con buena cobertura de países
REFERENCE_YEAR = 2022
TOP_N = 20  # Número de países a mostrar

# Filtramos solo países (Code ISO-3 de 3 letras) y el año de referencia
df_year = (
    df[
        (df['Year'] == REFERENCE_YEAR) &
        (df['Code'].str.len() == 3) &
        (df[POVERTY_COL].notna())
    ]
    .copy()
)

# Top N países con mayor pobreza extrema
top_countries = (
    df_year
    .nlargest(TOP_N, POVERTY_COL)
    [['Entity', POVERTY_COL, 'World region according to OWID', 'Population']]
    .reset_index(drop=True)
)

top_countries.index += 1  # ranking desde 1
print(f'✅ Top {TOP_N} países con mayor pobreza extrema en {REFERENCE_YEAR}:')
top_countries
# Out:
# ✅ Top 20 países con mayor pobreza extrema en 2022:
#                Entity  Share of population in poverty ($3 a day)  \
# 1          Mozambique                                  81.361377
# 2              Zambia                                  71.656150
# 3               Kenya                                  45.482665
# 4             Nigeria                                  41.819549
# 5                Chad                                  39.475375
# 6               Syria                                  17.961851
# 7        South Africa                                  17.435920
# 8            Colombia                                   9.266202
# 9          Tajikistan                                   8.852836
# 10  Equatorial Guinea                                   8.794199
# 11          Indonesia                                   7.853635
# 12            Georgia                                   7.733272
# 13         Bangladesh                                   5.909079
# ...

# %%
## 4. Gráfico de barras horizontal — Top 20 países

# %%
# Paleta de colores por región
REGION_COLORS = {
    'Africa'        : '#E05C5C',
    'Asia'          : '#5B8DB8',
    'South America' : '#6DBF88',
    'North America' : '#F5A623',
    'Europe'        : '#9B59B6',
    'Oceania'       : '#1ABC9C',
}
DEFAULT_COLOR = '#AAAAAA'

# Ordenar ascendente para que el mayor quede arriba
plot_data = top_countries.sort_values(POVERTY_COL, ascending=True).reset_index(drop=True)
regions   = plot_data['World region according to OWID']
colors    = [REGION_COLORS.get(r, DEFAULT_COLOR) for r in regions]

fig, ax = plt.subplots(figsize=(12, 8))

bars = ax.barh(
    plot_data['Entity'],
    plot_data[POVERTY_COL],
    color=colors,
    edgecolor='white',
    linewidth=0.6,
    height=0.7
)

# Etiquetas de valor al final de cada barra
for bar, val in zip(bars, plot_data[POVERTY_COL]):
    ax.text(
        bar.get_width() + 0.5,
        bar.get_y() + bar.get_height() / 2,
        f'{val:.1f}%',
        va='center', ha='left',
        fontsize=9, color='#333333'
    )

# Línea de referencia en 50%
ax.axvline(50, color='#CCCCCC', linewidth=1.2, linestyle='--', zorder=0)
ax.text(50.5, -0.8, '50%', fontsize=8, color='#999999')

# Eje X
ax.set_xlim(0, max(plot_data[POVERTY_COL]) + 10)
ax.xaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f%%'))
ax.tick_params(axis='x', labelsize=9)
ax.tick_params(axis='y', labelsize=10)

# Leyenda de regiones
used_regions = regions.unique()
handles = [
    plt.Rectangle((0, 0), 1, 1, color=REGION_COLORS.get(r, DEFAULT_COLOR))
    for r in used_regions
]
ax.legend(handles, used_regions, title='Región', loc='lower right',
          fontsize=9, title_fontsize=9, framealpha=0.7)

# Títulos
ax.set_title(
    f'Top {TOP_N} países con mayor pobreza extrema ({REFERENCE_YEAR})\n'
    '% de población con menos de $3 al día',
    fontsize=14, fontweight='bold', pad=16
)
ax.set_xlabel('Porcentaje de la población (%)', fontsize=10)

plt.tight_layout()
plt.savefig('pobreza_top20_barras.png', bbox_inches='tight', dpi=150)
plt.show()
print('✅ Gráfico guardado como pobreza_top20_barras.png')
# Out:
# ✅ Gráfico guardado como pobreza_top20_barras.png

# %%
## 5. Gráfico de dispersión — Pobreza vs. Población

# %%
fig, ax = plt.subplots(figsize=(11, 7))

# Todos los países del año de referencia para contexto
for region, group in df_year.groupby('World region according to OWID'):
    color = REGION_COLORS.get(region, DEFAULT_COLOR)
    ax.scatter(
        group['Population'],
        group[POVERTY_COL],
        color=color, alpha=0.65,
        s=group['Population'] / 3e6,  # tamaño proporcional a la población
        label=region, edgecolors='white', linewidths=0.4, zorder=3
    )

# Etiquetas solo para los TOP N
for _, row in top_countries.iterrows():
    country_row = df_year[df_year['Entity'] == row['Entity']]
    if not country_row.empty:
        ax.annotate(
            row['Entity'],
            xy=(country_row['Population'].values[0], country_row[POVERTY_COL].values[0]),
            fontsize=7.5, color='#333333',
            xytext=(5, 2), textcoords='offset points'
        )

ax.set_xscale('log')
ax.set_xlabel('Población (escala logarítmica)', fontsize=10)
ax.set_ylabel('% en pobreza extrema ($3/día)', fontsize=10)
ax.set_title(
    f'Pobreza extrema vs. Población por país ({REFERENCE_YEAR})\n'
    'Tamaño del punto proporcional a la población',
    fontsize=13, fontweight='bold', pad=14
)
ax.legend(title='Región', fontsize=8, title_fontsize=9,
          loc='upper right', framealpha=0.7)
ax.grid(True, linestyle='--', alpha=0.4, zorder=0)

plt.tight_layout()
plt.savefig('pobreza_dispersion.png', bbox_inches='tight', dpi=150)
plt.show()
print('✅ Gráfico guardado como pobreza_dispersion.png')
# Out:
# ✅ Gráfico guardado como pobreza_dispersion.png

# %%
## 6. Evolución histórica — Top 5 países más pobres

# %%
TOP5 = top_countries.head(5)['Entity'].tolist()
HISTORY_START = 1990

df_hist = df[
    (df['Entity'].isin(TOP5)) &
    (df['Year'] >= HISTORY_START) &
    (df[POVERTY_COL].notna())
].copy()

fig, ax = plt.subplots(figsize=(12, 6))

for country in TOP5:
    subset = df_hist[df_hist['Entity'] == country].sort_values('Year')
    color  = REGION_COLORS.get(
        subset['World region according to OWID'].iloc[0] if not subset.empty else '',
        DEFAULT_COLOR
    )
    ax.plot(subset['Year'], subset[POVERTY_COL],
            marker='o', markersize=4, linewidth=2,
            label=country, color=color)

ax.set_xlabel('Año', fontsize=10)
ax.set_ylabel('% en pobreza extrema ($3/día)', fontsize=10)
ax.set_title(
    f'Evolución histórica de la pobreza extrema ({HISTORY_START}–{REFERENCE_YEAR})\n'
    f'Top 5 países: {", ".join(TOP5)}',
    fontsize=13, fontweight='bold', pad=14
)
ax.legend(fontsize=9, framealpha=0.7)
ax.grid(True, linestyle='--', alpha=0.4)
ax.set_xlim(HISTORY_START, REFERENCE_YEAR + 1)

plt.tight_layout()
plt.savefig('pobreza_evolucion_historica.png', bbox_inches='tight', dpi=150)
plt.show()
print('✅ Gráfico guardado como pobreza_evolucion_historica.png')
# Out:
# ✅ Gráfico guardado como pobreza_evolucion_historica.png

# %%
## 7. Heatmap — Pobreza por región y año

# %%
YEARS_HEATMAP = list(range(2000, REFERENCE_YEAR + 1, 2))

df_heat = (
    df[
        (df['Year'].isin(YEARS_HEATMAP)) &
        (df['Code'].str.len() == 3) &
        (df[POVERTY_COL].notna())
    ]
    .groupby(['World region according to OWID', 'Year'])[POVERTY_COL]
    .mean()
    .unstack('Year')
)

fig, ax = plt.subplots(figsize=(13, 5))

sns.heatmap(
    df_heat,
    annot=True, fmt='.1f',
    cmap='YlOrRd',
    linewidths=0.5,
    ax=ax,
    cbar_kws={'label': '% en pobreza extrema (promedio regional)'}
)

ax.set_title(
    'Pobreza extrema promedio por región y año (2000–2022)\n% de población con menos de $3 al día',
    fontsize=13, fontweight='bold', pad=14
)
ax.set_xlabel('Año', fontsize=10)
ax.set_ylabel('Región', fontsize=10)
ax.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig('pobreza_heatmap_regional.png', bbox_inches='tight', dpi=150)
plt.show()
print('✅ Gráfico guardado como pobreza_heatmap_regional.png')
# Out:
# ✅ Gráfico guardado como pobreza_heatmap_regional.png

# %%
# 🌐 Análisis de Población Mundial con Proyecciones ONU
**Fuente:** UN World Population Prospects 2024 — procesado por Our World in Data  
Datos históricos: 1950–2023 | Proyecciones (escenario medio): 2024–2100
# Out:
#   Cell In[18], line 2
#     **Fuente:** UN World Population Prospects 2024 — procesado por Our World in Data
#     ^
# SyntaxError: invalid syntax

# %%
## 8. Carga del dataset de población

# %%
POP_CSV = 'data/population-with-un-projections/population-with-un-projections.csv'

pop = pd.read_csv(POP_CSV)

# Columnas de interés
POP_HIST = 'Population'
POP_PROJ = 'Population (Projected)'

# Columna unificada (histórico + proyección)
pop['pop_total'] = pop[POP_HIST].combine_first(pop[POP_PROJ])

print(f'Filas      : {len(pop):,}')
print(f'Años       : {pop["Year"].min()} – {pop["Year"].max()}')
print(f'Entidades  : {pop["Entity"].nunique()}')
pop.head()
# Out:
# Filas      : 39,562
# Años       : 1950 – 2100
# Entidades  : 262
#         Entity Code  Year  Population  Population (Projected)  pop_total
# 0  Afghanistan  AFG  1950   7776180.0                     NaN  7776180.0
# 1  Afghanistan  AFG  1951   7879343.0                     NaN  7879343.0
# 2  Afghanistan  AFG  1952   7987784.0                     NaN  7987784.0
# 3  Afghanistan  AFG  1953   8096703.0                     NaN  8096703.0
# 4  Afghanistan  AFG  1954   8207954.0                     NaN  8207954.0

# %%
## 9. Población mundial histórica y proyección al 2100

# %%
world = pop[pop['Entity'] == 'World'].copy()

hist = world[world[POP_HIST].notna()]
proj = world[world[POP_PROJ].notna()]

fig, ax = plt.subplots(figsize=(13, 6))

# Serie histórica
ax.fill_between(hist['Year'], hist[POP_HIST] / 1e9,
                alpha=0.25, color='#3A86FF')
ax.plot(hist['Year'], hist[POP_HIST] / 1e9,
        color='#3A86FF', linewidth=2.5, label='Histórico (1950–2023)')

# Serie proyectada
ax.fill_between(proj['Year'], proj[POP_PROJ] / 1e9,
                alpha=0.15, color='#FF6B6B')
ax.plot(proj['Year'], proj[POP_PROJ] / 1e9,
        color='#FF6B6B', linewidth=2.5, linestyle='--',
        label='Proyección ONU – escenario medio (2024–2100)')

# Línea de corte histórico/proyección
ax.axvline(2023, color='#999999', linewidth=1, linestyle=':')
ax.text(2023.3, 0.3, '2023\n(último dato real)', fontsize=8, color='#777777')

# Anotaciones clave
for year, label, offset in [(1987, '5 mil M', (2, 0.15)),
                             (1999, '6 mil M', (2, 0.15)),
                             (2011, '7 mil M', (2, 0.15)),
                             (2023, '8 mil M', (2, 0.15))]:
    val = world[world['Year'] == year]['pop_total'].values
    if len(val):
        ax.annotate(label,
                    xy=(year, val[0] / 1e9),
                    xytext=(year + offset[0], val[0] / 1e9 + offset[1]),
                    fontsize=8, color='#444444',
                    arrowprops=dict(arrowstyle='->', color='#AAAAAA', lw=0.8))

# Peak mundial aproximado según ONU
peak_row = proj.loc[proj[POP_PROJ].idxmax()]
ax.annotate(f'Pico estimado\n{peak_row[POP_PROJ]/1e9:.1f} mil M ({int(peak_row["Year"])})',
            xy=(peak_row['Year'], peak_row[POP_PROJ] / 1e9),
            xytext=(peak_row['Year'] - 20, peak_row[POP_PROJ] / 1e9 + 0.3),
            fontsize=9, color='#FF6B6B', fontweight='bold',
            arrowprops=dict(arrowstyle='->', color='#FF6B6B', lw=1.2))

ax.set_xlabel('Año', fontsize=10)
ax.set_ylabel('Población (miles de millones)', fontsize=10)
ax.set_title('Población mundial 1950–2100\nDatos históricos y proyección escenario medio ONU',
             fontsize=14, fontweight='bold', pad=14)
ax.legend(fontsize=9, framealpha=0.7)
ax.grid(True, linestyle='--', alpha=0.35)
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x:.1f} B'))

plt.tight_layout()
plt.savefig('poblacion_mundial_historica_proyeccion.png', bbox_inches='tight', dpi=150)
plt.show()
print('✅ Gráfico guardado como poblacion_mundial_historica_proyeccion.png')
# Out:
# ✅ Gráfico guardado como poblacion_mundial_historica_proyeccion.png

# %%
## 10. Top 10 países más poblados — 2023 vs 2100

# %%
# Filtrar solo países (ISO-3)
countries = pop[pop['Code'].str.len() == 3].copy()

top2023 = (countries[countries['Year'] == 2023]
           .nlargest(10, 'pop_total')[['Entity', 'pop_total']]
           .reset_index(drop=True))

top2100 = (countries[countries['Year'] == 2100]
           .nlargest(10, 'pop_total')[['Entity', 'pop_total']]
           .reset_index(drop=True))

fig, axes = plt.subplots(1, 2, figsize=(15, 6), sharey=False)

for ax, data, year, color in [
    (axes[0], top2023.sort_values('pop_total'), 2023, '#3A86FF'),
    (axes[1], top2100.sort_values('pop_total'), 2100, '#FF6B6B')
]:
    bars = ax.barh(data['Entity'], data['pop_total'] / 1e9,
                   color=color, alpha=0.85, edgecolor='white', height=0.65)
    for bar, val in zip(bars, data['pop_total'] / 1e9):
        ax.text(bar.get_width() + 0.02,
                bar.get_y() + bar.get_height() / 2,
                f'{val:.2f} B', va='center', ha='left', fontsize=9)
    ax.set_title(f'Top 10 países más poblados — {year}',
                 fontsize=12, fontweight='bold')
    ax.set_xlabel('Población (miles de millones)', fontsize=9)
    ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x:.1f} B'))
    ax.set_xlim(0, data['pop_total'].max() / 1e9 + 0.35)

plt.suptitle('¿Quiénes serán los países más poblados del mundo?',
             fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('poblacion_top10_2023_vs_2100.png', bbox_inches='tight', dpi=150)
plt.show()
print('✅ Gráfico guardado como poblacion_top10_2023_vs_2100.png')
# Out:
# ✅ Gráfico guardado como poblacion_top10_2023_vs_2100.png

# %%
## 11. Crecimiento poblacional por región (1950–2100)

# %%
REGIONS = ['Africa', 'Asia', 'Europe', 'North America', 'South America', 'Oceania']
REGION_PAL = {
    'Africa'       : '#E05C5C',
    'Asia'         : '#3A86FF',
    'Europe'       : '#9B59B6',
    'North America': '#F5A623',
    'South America': '#6DBF88',
    'Oceania'      : '#1ABC9C',
}

fig, ax = plt.subplots(figsize=(13, 7))

for region in REGIONS:
    subset = pop[pop['Entity'] == region].copy()
    color  = REGION_PAL.get(region, '#AAAAAA')

    hist_r = subset[subset[POP_HIST].notna()]
    proj_r = subset[subset[POP_PROJ].notna()]

    ax.plot(hist_r['Year'], hist_r[POP_HIST] / 1e9,
            color=color, linewidth=2.2, label=region)
    ax.plot(proj_r['Year'], proj_r[POP_PROJ] / 1e9,
            color=color, linewidth=2.2, linestyle='--')

    # Etiqueta al final (2100)
    last = proj_r[proj_r['Year'] == 2100]
    if not last.empty:
        ax.text(2101, last[POP_PROJ].values[0] / 1e9,
                f'{region}\n{last[POP_PROJ].values[0]/1e9:.2f} B',
                fontsize=7.5, va='center', color=color)

ax.axvline(2023, color='#CCCCCC', linewidth=1, linestyle=':')
ax.text(2023.5, 0.05, 'Proyección →', fontsize=8, color='#999999')

ax.set_xlim(1950, 2115)
ax.set_xlabel('Año', fontsize=10)
ax.set_ylabel('Población (miles de millones)', fontsize=10)
ax.set_title('Crecimiento poblacional por región — 1950 a 2100\n'
             'Línea continua: histórico | Línea discontinua: proyección ONU',
             fontsize=13, fontweight='bold', pad=14)
ax.legend(fontsize=9, loc='upper left', framealpha=0.7)
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x:.1f} B'))
ax.grid(True, linestyle='--', alpha=0.3)

plt.tight_layout()
plt.savefig('poblacion_regiones_1950_2100.png', bbox_inches='tight', dpi=150)
plt.show()
print('✅ Gráfico guardado como poblacion_regiones_1950_2100.png')
# Out:
# ✅ Gráfico guardado como poblacion_regiones_1950_2100.png

# %%
## 12. Composición regional de la población mundial (1950, 2023, 2100)

# %%
YEARS_PIE = [1950, 2023, 2100]

fig, axes = plt.subplots(1, 3, figsize=(16, 6))

for ax, year in zip(axes, YEARS_PIE):
    data = []
    for region in REGIONS:
        row = pop[(pop['Entity'] == region) & (pop['Year'] == year)]
        if not row.empty:
            val = row['pop_total'].values[0]
            if pd.notna(val):
                data.append((region, val))

    labels = [d[0] for d in data]
    values = [d[1] for d in data]
    colors = [REGION_PAL.get(l, '#AAAAAA') for l in labels]
    total  = sum(values)

    wedges, texts, autotexts = ax.pie(
        values, labels=None, colors=colors,
        autopct='%1.1f%%', startangle=90,
        pctdistance=0.78,
        wedgeprops=dict(edgecolor='white', linewidth=1.5)
    )
    for at in autotexts:
        at.set_fontsize(8)

    ax.set_title(f'{year}\nTotal: {total/1e9:.2f} B', fontsize=12, fontweight='bold')

# Leyenda compartida
handles = [plt.Rectangle((0,0),1,1, color=REGION_PAL[r]) for r in REGIONS]
fig.legend(handles, REGIONS, loc='lower center', ncol=6,
           fontsize=9, framealpha=0.7, bbox_to_anchor=(0.5, -0.04))

plt.suptitle('Distribución regional de la población mundial\n1950 · 2023 · 2100',
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('poblacion_pie_regional.png', bbox_inches='tight', dpi=150)
plt.show()
print('✅ Gráfico guardado como poblacion_pie_regional.png')
